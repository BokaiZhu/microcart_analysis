# %%
import sys
sys.path.append('../../toffy/')

import os
import shutil

import skimage.io as io
from toffy import rosetta
from toffy.panel_utils import load_panel
from toffy.image_stitching import get_max_img_size
from tmi.io_utils import list_folders, list_files
# this is using newer version toffy_envV2

# %% [markdown]
# this script performs rosetta compensation on MIBI raw images to correct for mass spectrum overlapping and containmination.
#
# Input of this script is raw TIFF images from MIBI scope results

# %%
#extracted_imgs_dir = '../../final_data/extracted/' # all extracted data stored here
extracted_imgs_dir = '../../final_data/extracted/micro_fine1ms/' # all extracted data stored here

#### runs to compensate
#run_names = ['2023-02-21T12-37-15-miceoFinaltest-Run1',
#             '2023-02-21T15-52-15-micro-finaltest-pureblockv'] # specific run name

#run_names = ['2023-02-28T12-53-51-DSST1-Run1',
#             '2023-03-01T24-02-56-DssT1-Run2'] # specific run name

#run_names = ['2023-03-03T18-26-40-DSS4-test-fine1ms-6pt-degrade'] # specific run name

#run_names = ['2023-03-04T16-22-15-DSSC1-Run1', '2023-03-04T19-46-22-DSSC1-Run2',
#            '2023-03-04T23-36-59-DSSC1-Run3', '2023-03-05T15-51-42-DSST2-Run1',
#            '2023-03-05T18-22-42-DSST2-Run2', '2023-03-05T21-42-35-DSST2-Run3',
#            '2023-03-05T23-58-06-DSST2-Run4', '2023-03-06T11-23-28-DSST2-Run5',
#            '2023-03-06T13-40-46-DSST2-Run6', '2023-03-06T16-15-43-DSSC2-Run1'] # specific run name

#run_names = ['2023-03-04T23-36-59-DSSC1-Run3'] # specific run name

#run_names = ['2023-03-07T18-32-49-DSSC2-Run5', '2023-03-07T16-08-39-DSSC2-Run4',
#            '2023-03-07T13-54-48-DSSC2-Run3', '2023-03-07T11-17-56-DSSC2-Run2',
#            '2023-03-09T15-53-36-DSSC3-Run4', '2023-03-09T13-34-52-DSSC3-Run3',
#            '2023-03-09T10-32-36-DSSC3-Run2', '2023-03-08T23-51-06-DSSC3-Run1',
#            '2023-03-08T21-26-09-DSST3-Run6', '2023-03-08T18-48-43-DSST3-Run5',
#            '2023-03-08T16-15-19-DSST3-Run4', '2023-03-08T14-03-50-DSST3-Run3',
#            '2023-03-08T11-39-28-DSST3-Run2', '2023-03-07T22-15-40-DSST3-Run1'] # specific run name

#run_names = ['2023-03-08T14-03-50-DSST3-Run3'] # naming error
#run_names = ['2023-03-08T11-39-28-DSST3-Run2', '2023-03-07T22-15-40-DSST3-Run1'] # naming error

run_names = ['2023-03-10T12-31-44-DSST4-Run1', '2023-03-10T14-47-38-DSST4-Run2', '2023-03-10T17-34-14-DSST4-Run3',
            '2023-03-18T14-36-10-DSST4-Run4', '2023-03-18T17-28-03-DSST4-Run5', '2023-03-18T23-11-36-DSST4-Run6',
            '2023-03-19T12-45-44-DSSC4-Run1', '2023-03-19T15-20-40-DSSC4-Run2', '2023-03-19T17-38-15-DSSC4-Run3',
            '2023-03-19T20-32-23-DSSC4-Run4', '2023-03-20T12-07-46-DSST1-Run1', '2023-03-20T14-32-22-DSST1-Run2',
            '2023-03-20T19-13-53-DSST1-Run3', '2023-03-20T21-44-51-DSST1-Run4', '2023-03-21T24-29-43-DSST1-Run5',
            '2023-03-21T10-32-42-DSST-Run6', '2023-03-21T12-44-51-DSST1-Run7', '2023-03-28T11-45-15-DSSC1-Run4'
            ]

#### panel used
panel_path = '../../final_data/Panel_micro_Bokai_2023-0224.csv' # panel that the run used
panel = load_panel(panel_path)
####

runs = run_names

#rosetta_image_dir = '../../final_data/compensated/' # place to store 
rosetta_image_dir = '../../final_data/compensated/micro_fine1ms/' # place to store 

final_rosetta_path = '../../final_data/commercial_rosetta_matrix_Nolan_expanded_mult_1.csv' # using multi 1 version
# Out:
# Panel_micro_Bokai_2023-0224.csv has the correct toffy format. Loading in panel data.

# %%
for run in runs:
    print("processing run {}".format(run))
    if not os.path.exists(os.path.join(rosetta_image_dir, run)):
        os.makedirs(os.path.join(rosetta_image_dir, run))
    rosetta.compensate_image_data(raw_data_dir=os.path.join(extracted_imgs_dir, run), 
                                  comp_data_dir=os.path.join(rosetta_image_dir, run), 
                                  comp_mat_path=final_rosetta_path, panel_info=panel, batch_size=1, gaus_rad = 0)
# Out:
# processing run 2023-03-10T12-31-44-DSST4-Run1
# Processing image 1
# Processing image 2
# Processing image 3
# Processing image 4
# Processing image 5
# processing run 2023-03-10T14-47-38-DSST4-Run2
# Processing image 1
# Processing image 2
# Processing image 3
# Processing image 4
# Processing image 5
# processing run 2023-03-10T17-34-14-DSST4-Run3
# Processing image 1
# Processing image 2
# Processing image 3
# Processing image 4
# Processing image 5
# processing run 2023-03-18T14-36-10-DSST4-Run4
# Processing image 1
# Processing image 2
# Processing image 3
# Processing image 4
# Processing image 5
# processing run 2023-03-18T17-28-03-DSST4-Run5
# Processing image 1
# Processing image 2
# Processing image 3
# Processing image 4
# Processing image 5
# processing run 2023-03-18T23-11-36-DSST4-Run6
# Processing image 1
# Processing image 2
# Processing image 3
# Processing image 4
# processing run 2023-03-19T12-45-44-DSSC4-Run1
# Processing image 1
# Processing image 2
# ...
